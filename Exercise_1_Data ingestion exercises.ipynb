# %%
#Using python 3.8.5
#!pip install flatten-json
#!pip install pytest
#!pip install ipytest

import warnings

warnings.filterwarnings("ignore") #just to keep clean
import pandas as pd
from flatten_json import flatten
import requests
import pytest
import ipytest

ipytest.autoconfig()

#getting JSON data and flattening
def get_clp_places(URL):
    try:
        re=requests.get(URL).json()                  #API call
        dict_data=(flatten(rec,".") for rec in re)   #Making into dict
        df=pd.DataFrame(dict_data)                   #Dict to DataFrame
        return df
    except:
        raise NotImplementedError("You need to develop this method!")

df_clp = get_clp_places("https://ecgplacesmw.colruytgroup.com/ecgplacesmw/v3/nl/places/filter/clp-places")
df_clp.head(10)
# Out:
#    placeId  ensign.id   ensign.name                 commercialName branchId  \
# 0      902          8  COLR_Colruyt                AALST (COLRUYT)     4156
# 1      946          8  COLR_Colruyt               AALTER (COLRUYT)     4218
# 2      950          8  COLR_Colruyt             AARSCHOT (COLRUYT)     4222
# 3      886          8  COLR_Colruyt            ALSEMBERG (COLRUYT)     4138
# 4      783          8  COLR_Colruyt                 AMAY (COLRUYT)     3853
# 5      650          8  COLR_Colruyt              ANDENNE (COLRUYT)     3596
# 6      669          8  COLR_Colruyt   ANDERLECHT (HERBETTELN) COLR     3620
# 7      744          8  COLR_Colruyt  ANDERLECHT (VEEWEYDE) COLRUYT     3759
# 8      448          8  COLR_Colruyt            ANDERLUES (COLRUYT)     3074
# 9      681          8  COLR_Colruyt                  ANS (COLRUYT)     3644
#
#   sourceStatus  placeType.id placeType.longName  \
# 0           AC             1             Winkel
# 1           AC             1             Winkel
# 2           AC             1             Winkel
# 3           AC             1             Winkel
# 4           AC             1             Winkel
# 5           AC             1             Winkel
# 6           AC             1             Winkel
# 7           AC             1             Winkel
# 8           AC             1             Winkel
# 9           AC             1             Winkel
#
#   placeType.placeTypeDescription sellingPartners.0  ...  \
# 0                         Winkel           QUALITY  ...
# 1                         Winkel           QUALITY  ...
# 2                         Winkel           QUALITY  ...
# 3                         Winkel           QUALITY  ...
# 4                         Winkel           QUALITY  ...
# 5                         Winkel           QUALITY  ...
# 6                         Winkel           QUALITY  ...
# 7                         Winkel           QUALITY  ...
# 8                         Winkel           QUALITY  ...
# 9                         Winkel           QUALITY  ...
#
#   placeSearchOpeningHours.0.date placeSearchOpeningHours.0.opens  \
# 0                     22-12-2022                             830
# 1                     22-12-2022                             830
# 2                     22-12-2022                             830
# 3                     22-12-2022                             830
# 4                     22-12-2022                             830
# 5                     22-12-2022                             830
# 6                     22-12-2022                             830
# 7                     22-12-2022                             830
# 8                     22-12-2022                             830
# 9                     22-12-2022                             830
#
#   placeSearchOpeningHours.0.closes  placeSearchOpeningHours.0.isToday  \
# 0                             2000                               True
# 1                             2000                               True
# 2                             2000                               True
# 3                             2000                               True
# 4                             2000                               True
# 5                             2000                               True
# 6                             2000                               True
# 7                             2000                               True
# 8                             2000                               True
# 9                             2000                               True
#
#    placeSearchOpeningHours.0.isOpenForTheDay placeSearchOpeningHours.1.date  \
# 0                                       True                     23-12-2022
# 1                                       True                     23-12-2022
# 2                                       True                     23-12-2022
# 3                                       True                     23-12-2022
# 4                                       True                     23-12-2022
# 5                                       True                     23-12-2022
# 6                                       True                     23-12-2022
# 7                                       True                     23-12-2022
# 8                                       True                     23-12-2022
# 9                                       True                     23-12-2022
#
#   placeSearchOpeningHours.1.opens placeSearchOpeningHours.1.closes  \
# 0                             800                             2100
# 1                             800                             2100
# 2                             800                             2100
# 3                             800                             2100
# 4                             800                             2100
# 5                             800                             2100
# 6                             800                             2100
# 7                             800                             2100
# 8                             800                             2100
# 9                             800                             2100
#
#   placeSearchOpeningHours.1.isToday placeSearchOpeningHours.1.isOpenForTheDay
# 0                             False                                      True
# 1                             False                                      True
# 2                             False                                      True
# 3                             False                                      True
# 4                             False                                      True
# 5                             False                                      True
# 6                             False                                      True
# 7                             False                                      True
# 8                             False                                      True
# 9                             False                                      True
#
# [10 rows x 33 columns]

# %%
df_clp.info() # just to look at all the columns and dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 33 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   placeId                                    257 non-null    int64
#  1   ensign.id                                  257 non-null    int64
#  2   ensign.name                                257 non-null    object
#  3   commercialName                             257 non-null    object
#  4   branchId                                   257 non-null    object
#  5   sourceStatus                               257 non-null    object
#  6   placeType.id                               257 non-null    int64
#  7   placeType.longName                         257 non-null    object
#  8   placeType.placeTypeDescription             257 non-null    object
#  9   sellingPartners.0                          251 non-null    object
#  10  sellingPartners.1                          246 non-null    object
#  11  handoverServices.0                         251 non-null    object
#  12  handoverServices.1                         246 non-null    object
#  13  geoCoordinates.latitude                    257 non-null    float64
#  14  geoCoordinates.longitude                   257 non-null    float64
#  15  address.streetName                         257 non-null    object
#  16  address.houseNumber                        257 non-null    object
#  17  address.postalcode                         257 non-null    object
#  18  address.cityName                           257 non-null    object
#  19  address.countryName                        257 non-null    object
#  20  moreInfoUrl                                257 non-null    object
#  21  routeUrl                                   257 non-null    object
#  22  isActive                                   257 non-null    bool
#  23  placeSearchOpeningHours.0.date             257 non-null    object
#  24  placeSearchOpeningHours.0.opens            257 non-null    int64
#  25  placeSearchOpeningHours.0.closes           257 non-null    int64
#  26  placeSearchOpeningHours.0.isToday          257 non-null    bool
#  27  placeSearchOpeningHours.0.isOpenForTheDay  257 non-null    bool
#  28  placeSearchOpeningHours.1.date             257 non-null    object
#  29  placeSearchOpeningHours.1.opens            257 non-null    int64
#  30  placeSearchOpeningHours.1.closes           257 non-null    int64
#  31  placeSearchOpeningHours.1.isToday          257 non-null    bool
#  32  placeSearchOpeningHours.1.isOpenForTheDay  257 non-null    bool
# dtypes: bool(5), float64(2), int64(7), object(19)
# memory usage: 57.6+ KB

# %%
#Quality Checks

#Checking the total records if > 200
def test_record_check():
    assert len(df_clp) > 200
    
#Checking latitude max and min values are within bounds
def test_min_max_latitude():
    assert 49 < df_clp['geoCoordinates.latitude'].min()
    assert 52 > df_clp['geoCoordinates.latitude'].max()
    
#Checking longitude max and min values are within bounds
def test_min_max_longitude():
    assert 2 < df_clp['geoCoordinates.longitude'].min()
    assert 7 > df_clp['geoCoordinates.longitude'].max()

# %%
# Feature creation - 'antwerpen'

def check_name(x):
    result=0
    if "antwerpen" in x.lower():
        result=1
    return result
    
df_clp["antwerpen"]=df_clp['address.cityName'].apply(check_name)


#Checking if the column existis in the DataFrame.
def test_check_column():
    assert {"antwerpen"}.issubset(df_clp.columns)
    
#Checking if both 0 and 1 exists in column.
def test_values_in_cols():
    assert df_clp["antwerpen"].unique().tolist() == [0,1]

# Running all tests
ipytest.run()
# Out:
# .....                                                                                        [100%]
# 5 passed in 0.27s
# <ExitCode.OK: 0>

# %%
df_clp["antwerpen"].value_counts()
# Out:
# 0    251
# 1      6
# Name: antwerpen, dtype: int64
